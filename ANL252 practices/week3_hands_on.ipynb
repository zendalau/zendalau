# %%
tuple1 = ('ANL252', 60 , 'Test' , 10) 
print(tuple1)
# Out:
# ('ANL252', 60, 'Test', 10)

# %%
print(tuple1[0])
print(tuple1[1])
print(tuple1[3])
# Out:
# ANL252
# 60
# 10

# %%
tuple1[1] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tuple1[1] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple2 = (1,2,1,2,'ANL252', 'ANL252')
print(tuple2)
# Out:
# (1, 2, 1, 2, 'ANL252', 'ANL252')

# %%
print(tuple2[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(tuple2[6])
#
# IndexError: tuple index out of range

# %%
print(tuple2[2])
print(tuple2[-2])
# Out:
# 1
# ANL252

# %%
print(tuple2[3:5])

print('IMPORTANT: The end index is NOT included in the subsetting procedure')
# Out:
# (2, 'ANL252')
# IMPORTANT: The end index is NOT included in the subsetting procedure

# %%
fruits = ('APPLE', 'ORANGE', 'BANANA')
fruits_subset = fruits[-3:-1]
print(fruits_subset)
print('this is in reverse order from the last element')
# Out:
# ('APPLE', 'ORANGE')
# this is in reverse order from the last element

# %%
print(fruits)
for x in fruits:
    print(x)
    print(x)
    print("hi")
    print('nihao')

    
print('hello')
# Out:
# ('APPLE', 'ORANGE', 'BANANA')
# APPLE
# APPLE
# hi
# nihao
# ORANGE
# ORANGE
# hi
# nihao
# BANANA
# BANANA
# hi
# nihao
# hello

# %%
print('len = tuple length')
len(tuple2)
# Out:
# len = tuple length
# 6

# %%
tuple3 = tuple1 + tuple2
print(tuple3)

print('concat tuple')
# Out:
# ('ANL252', 60, 'Test', 10, 1, 2, 1, 2, 'ANL252', 'ANL252')
# concat tuple

# %%
tuple4 = 'nicole','crystal','zenda'
tuple5 = 20,21,22
print(tuple4)
print(tuple5)
# Out:
# ('nicole', 'crystal', 'zenda')
# (20, 21, 22)

# %%
len(tuple4)
# Out:
# 3

# %%
len(tuple5)
# Out:
# 3

# %%
for i in range (0,2):
    print(tuple4[i])


print('remember that the last element is -1')
# Out:
# nicole
# crystal
# remember that the last element is -1

# %%
tuple6 = tuple4+tuple5
print(tuple6)
# Out:
# ('nicole', 'crystal', 'zenda', 20, 21, 22)

# %%
list1 = ['Apple','Orange','Banana']
print(list1)

print('list uses [ ] and is editable. tuple uses ( ) and is NOT editable')
# Out:
# ['Apple', 'Orange', 'Banana']
# list uses [ ] and is editable. tuple uses ( ) and is NOT editable

# %%
list1[0] = 'Mango'

print(list1)
print('Changes the 0 element from Apple to Mango')
# Out:
# ['Mango', 'Orange', 'Banana']
# Changes the 0 element from Apple to Mango

# %%
list2 = (('Alice',20),('Ben',25),('James',18))
print(list2[0])
# Out:
# ('Alice', 20)

# %%
for i in list2:
    print (i)
# Out:
# ('Alice', 20)
# ('Ben', 25)
# ('James', 18)

# %%
list1
# Out:
# ['Mango', 'Orange', 'Banana']

# %%
list1[1] = 'Strawberry'
print (list1)

list1[0:3] = 'Pear','Guava','Papaya'
print(list1)
# Out:
# ['Mango', 'Strawberry', 'Banana']
# ['Pear', 'Guava', 'Papaya']

# %%
list1[0]
# Out:
# 'Pear'

# %%
list1[0:1]
# Out:
# ['Pear']

# %%
list1[0:1] = 'Mango'
print(list1)
# Out:
# ['M', 'a', 'n', 'g', 'o', 'Guava', 'Papaya']

# %%
name_list = ['Alice','Ben','Zenda']
age_list = [20,18,26]
name_age_list_MERGE = [name_list,age_list]
print(name_age_list_MERGE)


print('MERGIING IS NOT CONCAT. CONCAT IS TO COMBINE EVERYTH TOGETHER. MERGE IS COMBINE 2 SETS OF LISTS')
# Out:
# [['Alice', 'Ben', 'Zenda'], [20, 18, 26]]
# MERGIING IS NOT CONCAT. CONCAT IS TO COMBINE EVERYTH TOGETHER. MERGE IS COMBINE 2 SETS OF LISTS

# %%
print(name_age_list_MERGE[0][2])
print(name_age_list_MERGE[1][2])
# Out:
# Zenda
# 26

# %%
fruits = ["Apple","Orange","Banana"]
vege = ["Spinach","Lettuce","Cabbage"]
combine_list = [fruits,vege]

print(fruits)
print(vege)
print(combine_list)
# Out:
# ['Apple', 'Orange', 'Banana']
# ['Spinach', 'Lettuce', 'Cabbage']
# [['Apple', 'Orange', 'Banana'], ['Spinach', 'Lettuce', 'Cabbage']]

# %%
for x in vege:
    print (x)
    print ('healthy vege')
# Out:
# Spinach
# healthy vege
# Lettuce
# healthy vege
# Cabbage
# healthy vege

# %% [markdown]
# ## Example program

# %%
List1 = ['Zenda','Zavier','Zeshon']
List2 = [26,22,20]

print(List1)
print(List2)
# Out:
# ['Zenda', 'Zavier', 'Zeshon']
# [26, 22, 20]

# %%
List2[1] = 30
print(List2)
# Out:
# [26, 30, 20]

# %%
print (List2)

for x in List2:
    print(x)
# Out:
# [26, 30, 20]
# 26
# 30
# 20

# %%
for z in range(0,2):
    print(List1[z])
# Out:
# Zenda
# Zavier

# %%
siblings_age_concat = List1+List2
print(siblings_age_concat)
# Out:
# ['Zenda', 'Zavier', 'Zeshon', 26, 30, 20]

# %%
siblings_age_merge = [List1,List2]
print(siblings_age_merge)
# Out:
# [['Zenda', 'Zavier', 'Zeshon'], [26, 30, 20]]
